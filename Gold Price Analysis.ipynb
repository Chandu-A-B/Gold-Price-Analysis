# %% [markdown]
# # Gold Price Analysis

# %%
#importing modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\CHANDU\\Desktop\\Gold_Price_Analysis\\GoldRate_Analysis.csv")

# %%
df
# Out:
#         Month        Date        Day  Closing  Highest  Lowest
# 0     January  01-01-2021     Friday     5026     5026    5009
# 1     January  02-01-2021   Saturday     5026     5026    5026
# 2     January  03-01-2021     Sunday     5026     5026    5026
# 3     January  04-01-2021     Monday     5086     5101    5026
# 4     January  05-01-2021    Tuesday     5123     5137    5101
# ..        ...         ...        ...      ...      ...     ...
# 360  December  27-12-2021     Monday     4815     4823    4806
# 361  December  28-12-2021    Tuesday     4812     4822    4807
# 362  December  29-12-2021  Wednesday     4774     4805    4763
# 363  December  30-12-2021   Thursday     4774     4786    4763
# 364  December  31-12-2021     Friday     4811     4811    4782
#
# [365 rows x 6 columns]

# %%
df.shape
# Out:
# (365, 6)

# %%
df.head()
# Out:
#      Month        Date       Day  Closing  Highest  Lowest
# 0  January  01-01-2021    Friday     5026     5026    5009
# 1  January  02-01-2021  Saturday     5026     5026    5026
# 2  January  03-01-2021    Sunday     5026     5026    5026
# 3  January  04-01-2021    Monday     5086     5101    5026
# 4  January  05-01-2021   Tuesday     5123     5137    5101

# %%
df.dtypes
# Out:
# Month      object
# Date       object
# Day        object
# Closing     int64
# Highest     int64
# Lowest      int64
# dtype: object

# %%
df.nunique()
# Out:
# Month       12
# Date       365
# Day          7
# Closing    227
# Highest    216
# Lowest     207
# dtype: int64

# %%
df['Date'].nunique()
# Out:
# 365

# %%
df['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
df['Day'].unique()
# Out:
# array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday'], dtype=object)

# %%
df['Month'].groupby(df['Day']).count().sort_values(ascending=False)
# Out:
# Day
# Friday       53
# Monday       52
# Saturday     52
# Sunday       52
# Thursday     52
# Tuesday      52
# Wednesday    52
# Name: Month, dtype: int64

# %%
#pie chart
labels = 'Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday'
sizes = [52,52,52,52,53,52,52]
fig, ax = plt.subplots(figsize=(10,7))
fig.set_facecolor('white')
ax.pie(sizes, labels=labels, colors=["#EF233C","#eb5e28","#3a0ca3","#36b5ff","#b09ae3","#d68c45","#00bbf9"],
       autopct='%1.1f%%', startangle=60,textprops={'color':'black','weight':'bold','fontsize':13.5})
ax.axis('equal')
plt.show()

# %%
df['Month'].groupby(df['Month']).count().sort_values()
# Out:
# Month
# February     28
# April        30
# June         30
# November     30
# September    30
# August       31
# December     31
# January      31
# July         31
# March        31
# May          31
# October      31
# Name: Month, dtype: int64

# %% [markdown]
# # Scatter Plot for Lowest Prices

# %%
fig, axs = plt.subplots(figsize=(15,5))
ax=sns.stripplot(x=df.Month, y=df.Lowest)
plt.title('Scatter Plot for Lowest Prices')
plt.grid()
plt.show()

# %% [markdown]
# # Scatter Plot for Highest Prices

# %%
fig, axs = plt.subplots(figsize=(15,5))
ax=sns.stripplot(x=df.Month, y=df.Highest)
plt.title('Scatter Plot for Highest Prices')
plt.grid()
plt.show()

# %% [markdown]
# # Scatter Plot for Closing Prices

# %%
fig, axs = plt.subplots(figsize=(15,5))
ax=sns.stripplot(x=df.Month, y=df.Closing)
plt.title('Scatter Plot for Closing Prices')
plt.grid()
plt.show()

# %% [markdown]
# # Month wise Lowest Price

# %%
plt.rcParams["figure.figsize"] = [16, 4]
for eachMonth in ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]:
    myNewDataFrame = df[df.Month == eachMonth]
#     print(myNewDataFrame)
    yAxis = myNewDataFrame.Lowest
    xAxis = myNewDataFrame.Date
    plt.plot(xAxis, yAxis, marker='.', markerfacecolor="black", markersize=8, color='#C99E10', linewidth=3)
    plt.title(str(eachMonth+"- Lowest Prices"))
    plt.grid()
    plt.xticks(rotation=-45)
    plt.show()

# %% [markdown]
# # Month wise Highest Price

# %%
plt.rcParams["figure.figsize"] = [16, 4]
for eachMonth in ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]:
    myNewDataFrame = df[df.Month == eachMonth]
#     print(myNewDataFrame)
    yAxis = myNewDataFrame.Highest
    xAxis = myNewDataFrame.Date
    plt.plot(xAxis, yAxis, marker='.', markerfacecolor="black", markersize=10, color='#C99E10', linewidth=3)
    plt.title(str(eachMonth+"- Highest Prices"))
    plt.grid()
    plt.xticks(rotation=-45)
    plt.show()

# %% [markdown]
# # Month wise Closing Prices

# %%
plt.rcParams["figure.figsize"] = [16, 4]
for eachMonth in ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]:
    myNewDataFrame = df[df.Month == eachMonth]
#     print(myNewDataFrame)
    yAxis = myNewDataFrame.Closing
    xAxis = myNewDataFrame.Date
    plt.plot(xAxis, yAxis, marker='.', markerfacecolor="black", markersize=10, color='#C99E10', linewidth=3)
    plt.title(str(eachMonth+"- Closing Prices"))
    plt.grid()
    plt.xticks(rotation=-45)
    plt.show()
